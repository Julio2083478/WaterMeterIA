# %% [markdown]
# <a href="https://colab.research.google.com/github/Julio2083478/WaterMeterIA/blob/main/Entrenamiento_yolov8m_segmentaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Instalación de ultralytics e importación de librerias

# %%
# !pip install ultralytics==8.0.28

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.2/78.2 GB disk)

# %% [markdown]
# ##Carga del dataset

# %%
# !mkdir datasets
# %cd datasets

# !pip install roboflow --quiet


from roboflow import Roboflow
rf = Roboflow(api_key="BL7EzMRRtWpiWWHOsLyr")
project = rf.workspace("tesis-y4byt").project("medidorr200")
dataset = project.version(2).download("yolov8")
# Out:
# /content/datasets
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 19.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 7.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.9 MB/s eta 0:00:00
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.28, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to medidorr200-2 in yolov8:: 100%|██████████| 2790/2790 [00:00<00:00, 3945.01it/s]

# %% [markdown]
# #Se configuran los parametros de entrenamietno

# %%
# !yolo task=segment mode=train model=yolov8m-seg.pt data=/content/datasets/medidorr200-2/data.yaml epochs=300 imgsz=224 patience=50 optimizer=SGD weight_decay=0.0005 batch=16 lr0=0.01
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ##Montar el drive

# %% [markdown]
# ##Se guarda el modelo en el drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil

source_folder_path = '/content/datasets/runs'
destination_folder_path = '/content/drive/MyDrive/entrenamiento/YOLOV8m_segmentar224'

shutil.copytree(source_folder_path, destination_folder_path)
# Out:
# '/content/drive/MyDrive/entrenamiento/YOLOV8m_segmentar224'

# %%
# !yolo task=segment mode=val model=/content/datasets/runs/segment/train4/weights/best.pt data=/content/datasets/medidorr200-2/data.yaml
# Out:
# 2023-07-02 01:35:55.370986: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-02 01:35:56.194119: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m-seg summary (fused): 245 layers, 27222963 parameters, 0 gradients, 110.0 GFLOPs
# val: Scanning /content/datasets/medidorr200-2/valid/labels.cache... 116 images, 0 backgrounds, 0 corrupt: 100% 116/116 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 8/8 [00:03<00:00,  2.34it/s]
# ...
