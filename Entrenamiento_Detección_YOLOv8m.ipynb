# %% [markdown]
# <a href="https://colab.research.google.com/github/Julio2083478/WaterMeterIA/blob/main/Entrenamiento_Detecci%C3%B3n_YOLOv8m.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instalcación de dependencias

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Instalación de ultralytics e importación de librerias

# %%
# !pip install ultralytics==8.0.28

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.2/78.2 GB disk)

# %% [markdown]
# ##Carga del dataset

# %%
# !mkdir datasets
# %cd datasets

# !pip install roboflow --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="BL7EzMRRtWpiWWHOsLyr")
project = rf.workspace("tesis-y4byt").project("medidordeteccion")
dataset = project.version(2).download("yolov8")
# Out:
# /content/datasets
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 13.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.7 MB/s eta 0:00:00
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.28, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to medidordeteccion-2 in yolov8:: 100%|██████████| 2900/2900 [00:00<00:00, 2926.81it/s]

# %% [markdown]
# #Se configuran los parametros de entrenamietno

# %%
# !yolo task=train model=yolov8m.pt data=/content/datasets/medidordeteccion-2/data.yaml epochs=300 imgsz=640 patience=50 optimizer=SGD  batch=16 lr0=0.01
# Out:
# WARNING ⚠️ 'mode=' is missing. Valid modes are ('train', 'val', 'predict', 'export'). Using default 'mode=train'.
# WARNING ⚠️ 'task=train' conflicts with detect model yolov8m.pt. Inheriting 'task=detect' from yolov8m.pt and ignoring 'task=train'.
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ##Se guarda el modelo en el drive

# %%
import shutil

# Definir la ruta de la carpeta de origen en Google Colab
ruta_origen = '/content/datasets/runs'

# Definir la ruta de la carpeta de destino en Google Drive
ruta_destino = '/content/drive/MyDrive/YOLODETECparadejarr'

# Copiar la carpeta de origen a la carpeta de destino
shutil.copytree(ruta_origen, ruta_destino)

print('Carpeta copiada con éxito a tu Google Drive.')
# Out:
# Carpeta copiada con éxito a tu Google Drive.

# %% [markdown]
# ##Prueba en conjunto de validación

# %%
# !yolo task=detect mode=val model=/content/datasets/runs/detect/train2/weights/best.pt data=/content/datasets/medidordeteccion-2/data.yaml
# Out:
# 2023-06-30 01:57:54.315122: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-30 01:57:55.138997: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25845550 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/datasets/medidordeteccion-2/valid/labels.cache... 86 images, 1 backgrounds, 0 corrupt: 100% 86/86 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 6/6 [00:08<00:00,  1.43s/it]
#                    all         86        680      0.946      0.969      0.963      0.571
# ...
